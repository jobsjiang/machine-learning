# %% [markdown]
# https://mp.weixin.qq.com/s?__biz=MzAxMjMwODMyMQ==&mid=2456357410&idx=3&sn=9e9b6f928c4f627c6c3db00e8feec037&chksm=8c2e702cbb59f93a5f43ae1e69502f266766185686e655eafc75f765d1e166763ee71b725390&scene=126&sessionid=1601434961&key=&ascene=1&uin=MjA1MjAyODkxNg%3D%3D&devicetype=Windows+10+x64&version=6300002f&lang=zh_CN&exportkey=AURmApesMfL2R2Z2oqvEO6E%3D&pass_ticket=8Rw8nkLHB0Sr7SjF3yqfEl7Lvt2mSLf5IpZZMJEyG%2FeULQMEC7XtBro1tis0A91k&wx_header=0

# %%
import pandas as pd
import numpy as np

# %%
# 1.转换值
df = pd.DataFrame({'A': [1,2,3], 'B': [10,20,30] })
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
def plus_10(x):
    return x + 10
df.transform(plus_10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df.transform(lambda x : x + 10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
# 字符串函数
df.transform('sqrt')
# Out:
#           A         B
# 0  1.000000  3.162278
# 1  1.414214  4.472136
# 2  1.732051  5.477226

# %%
# 函数列表
df.transform([np.sqrt,np.exp])
# Out:
#           A                    B
#        sqrt        exp      sqrt           exp
# 0  1.000000   2.718282  3.162278  2.202647e+04
# 1  1.414214   7.389056  4.472136  4.851652e+08
# 2  1.732051  20.085537  5.477226  1.068647e+13

# %%
df.transform({
    'A':np.sqrt,
    'B':np.exp,
})
# Out:
#           A             B
# 0  1.000000  2.202647e+04
# 1  1.414214  4.851652e+08
# 2  1.732051  1.068647e+13

# %%
# 组合groupby
df = pd.DataFrame({
  'restaurant_id': [101,102,103,104,105,106,107],
  'address': ['A','B','C','D', 'E', 'F', 'G'],
  'city': ['London','London','London','Oxford','Oxford', 'Durham', 'Durham'],
  'sales': [10,500,48,12,21,22,14]
})
df
# Out:
#    restaurant_id address    city  sales
# 0            101       A  London     10
# 1            102       B  London    500
# 2            103       C  London     48
# 3            104       D  Oxford     12
# 4            105       E  Oxford     21
# 5            106       F  Durham     22
# 6            107       G  Durham     14

# %%
df['city_total_sales'] = df.groupby('city')['sales'].transform('sum')

# %%
df
# Out:
#    restaurant_id address    city  sales  city_total_sales
# 0            101       A  London     10               558
# 1            102       B  London    500               558
# 2            103       C  London     48               558
# 3            104       D  Oxford     12                33
# 4            105       E  Oxford     21                33
# 5            106       F  Durham     22                36
# 6            107       G  Durham     14                36

# %%
# 计算百分比
df['pct'] = df['sales'] / df['city_total_sales']
df['pct'] = df['pct'].apply(lambda x: format(x, '.2%'))

# %%
# 过滤数据
df[df.groupby('city')['sales'].transform('sum') > 40]
# Out:
#    restaurant_id address    city  sales  city_total_sales     pct
# 0            101       A  London     10               558   1.79%
# 1            102       B  London    500               558  89.61%
# 2            103       C  London     48               558   8.60%

# %%
# 在组级别处理丢失的值
df = pd.DataFrame({
    'name': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'value': [1, np.nan, np.nan, 2, 8, 2, np.nan, 3]
})

# %%
df
# Out:
#   name  value
# 0    A    1.0
# 1    A    NaN
# 2    B    NaN
# 3    B    2.0
# 4    B    8.0
# 5    C    2.0
# 6    C    NaN
# 7    C    3.0

# %%
df.groupby('name').transform(lambda x:x.fillna(x.mean()))
# Out:
#    value
# 0    1.0
# 1    1.0
# 2    5.0
# 3    2.0
# 4    8.0
# 5    2.0
# 6    2.5
# 7    3.0
